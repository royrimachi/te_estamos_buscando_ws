# %% [markdown]
# # Series

# %%
import pandas as pd

# series_test = pd.Series([100, 200, 300])

# series_test

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39],
                           2000: [34, 32, 32],
                           2001: [23, 39, 12]})
frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    12

# %%
frame_test2 = pd.DataFrame([[74, 38, 39],
                            [34, 32, 32], 
                            [23, 39, 12]], columns=[1999, 2000, 2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    12

# %% [markdown]
# # Read data

# %%
import pandas as pd

TEB_encontrados = pd.read_csv('teestamosbuscando_2019_11_25_found_people_profiles.csv', encoding='latin-1')

TEB_encontrados
# Out:
#        age                                      circumstances  \
# 0     15.0                             Salió de su domicilio.
# 1     14.0  Salió de su domicilio sin decir nada llevándos...
# 2     14.0                                                NaN
# 3     12.0  Salió de su domicilio a botar la basura y no r...
# 4     13.0  Se dirigía a su domicilio en compañía de su pr...
# ...    ...                                                ...
# 2051  15.0  Salio de su domicilio ubicado en Pasaje la Mer...
# 2052  12.0  Salió del puesto de pollos ubicado en la Av. H...
# 2053  17.0         Salió de su domicilio sin indicar destino.
# 2054   9.0                                                NaN
# 2055  14.0  Salió de su domicilio con dirección a su insti...
#
#                                                clothing  \
# 0                                  Uniforme de colegio.
# 1     Pantalón jean rasgado negro, polo azul, sandal...
# ...

# %%
eye_valid_colors = pd.Series(
    {
        'Black': 0, 
        'Brown': 1, 
        'Amber': 2,
        'Hazel': 3,
        'Green': 4,
        'Blue': 5,
        'Gray': 6
        
    })
eye_valid_colors
# Out:
# Black    0
# Brown    1
# Amber    2
# Hazel    3
# Green    4
# Blue     5
# Gray     6
# dtype: int64

# %%
TEB_encontrados['eyes_color'].value_counts()
# Out:
# NEGROS                          500
# COLOR NEGRO                     387
# PARDOS                          244
# MARRONES                        132
# CASTAÑOS                        127
#                                ...
# GRANDES MARRONES                  1
# NEGROS RASGADOS                   1
# MARRONES OSCUROS Y ACHINADOS      1
# ACHINADOS COLOR NEGRO             1
# GRANDES MARRONES OSCUROS          1
# Name: eyes_color, Length: 101, dtype: int64

# %%
aux = TEB_encontrados[TEB_encontrados['eyes_color'].str.contains('COL|col').fillna(False)]
aux['eyes_color'].value_counts()
# Out:
# COLOR NEGRO               387
# COLOR  NEGRO              123
# COLOR MARRÓN               23
# COLOR GRIS                  5
# COLOR NEGROS                4
# COLOR MARRÓN CLARO          3
# COLOR MARRÓN OSCURO         3
# COLOR PARDO                 3
# COLOR CAFÉ                  2
# COLOR AVELLANA              2
# COLOR NEGRO ACHINADOS       2
# COLOR NEGRO GRANDES         1
# COLOR  NEGRO GRANDES        1
# NORMALES COLOR NEGRO        1
# PEQUEÑOS COLOR  NEGRO       1
# RASGADOS COLOR CAFÉ         1
# COLOR  NEGRO ACHINADOS      1
# ACHINADOS COLOR NEGRO       1
# COLOR VERDE                 1
# MEDIANOS COLOR NEGRO        1
# Name: eyes_color, dtype: int64

# %%
black_eyes = TEB_encontrados[TEB_encontrados['eyes_color'].str.contains('NEGR|OSCURO|NORM|CHIN').fillna(False)]
black_eyes
# Out:
#        age                                      circumstances  \
# 0     15.0                             Salió de su domicilio.
# 1     14.0  Salió de su domicilio sin decir nada llevándos...
# 3     12.0  Salió de su domicilio a botar la basura y no r...
# 4     13.0  Se dirigía a su domicilio en compañía de su pr...
# 6     17.0                      Con dirección a su domicilio.
# ...    ...                                                ...
# 2051  15.0  Salio de su domicilio ubicado en Pasaje la Mer...
# 2052  12.0  Salió del puesto de pollos ubicado en la Av. H...
# 2053  17.0         Salió de su domicilio sin indicar destino.
# 2054   9.0                                                NaN
# 2055  14.0  Salió de su domicilio con dirección a su insti...
#
#                                                clothing  \
# 0                                  Uniforme de colegio.
# 1     Pantalón jean rasgado negro, polo azul, sandal...
# ...

# %%
no_black_eyes = TEB_encontrados[~TEB_encontrados['eyes_color'].str.contains('NEGR|OSCURO|NORM|CHIN').fillna(False)]
no_black_eyes
# Out:
#        age                                      circumstances  \
# 2     14.0                                                NaN
# 5     14.0  Salió de su inmueble con dirección al centro e...
# 7     10.0  Por las inmediaciones del interior del colegio...
# 8     14.0                Por las inmediaciones de la Demuna.
# 13    17.0  Salió de su casa con dirección a tomarse una f...
# ...    ...                                                ...
# 2041  16.0  Que se salio de la casa de su abuela en el dis...
# 2044  15.0  que salio de su domicilio Mz L  Lt. 34 Los Por...
# 2046  14.0  El 14 de octubre del 2017 a horas 07:30 aprox....
# 2047  16.0  Que salio de la casa de su conviviente, en com...
# 2048  13.0  Que salió de su domicilio ubicado en Mz. D-23 ...
#
#                                                clothing  \
# 2          Blusa blanca, short negro y sandalias rojas.
# 5     Pantalón verde, camisa beige, casaca verde con...
# ...

# %%
brown_eyes = no_black_eyes[no_black_eyes['eyes_color'].str.contains('MARR|CASTAÑO|PARD|CAF|CLAR').fillna(False)]
brown_eyes
# Out:
#        age                                      circumstances  \
# 2     14.0                                                NaN
# 5     14.0  Salió de su inmueble con dirección al centro e...
# 7     10.0  Por las inmediaciones del interior del colegio...
# 8     14.0                Por las inmediaciones de la Demuna.
# 13    17.0  Salió de su casa con dirección a tomarse una f...
# ...    ...                                                ...
# 2041  16.0  Que se salio de la casa de su abuela en el dis...
# 2044  15.0  que salio de su domicilio Mz L  Lt. 34 Los Por...
# 2046  14.0  El 14 de octubre del 2017 a horas 07:30 aprox....
# 2047  16.0  Que salio de la casa de su conviviente, en com...
# 2048  13.0  Que salió de su domicilio ubicado en Mz. D-23 ...
#
#                                                clothing  \
# 2          Blusa blanca, short negro y sandalias rojas.
# 5     Pantalón verde, camisa beige, casaca verde con...
# ...

# %%
no_brown_eyes = no_black_eyes[~no_black_eyes['eyes_color'].str.contains('MARR|CASTAÑO|PARD|CAF|CLAR').fillna(False)]
no_brown_eyes
# Out:
#        age                                      circumstances  \
# 47    16.0                             Salió de su domicilio.
# 72    13.0  En que salió de su domicilio ubicado en Jr. Hu...
# 101   15.0                             Salió de su domicilio.
# 104   14.0                                                NaN
# 105   14.0                                     Salió de casa.
# ...    ...                                                ...
# 1980  15.0  Que salió de su domicilio ubicado en Block Q15...
# 1983  14.0  En horas de madrugada se fugó  de su hogar en ...
# 1986  16.0  En horas de la madrugada se fugó de su hogar e...
# 2016   7.0  Según su progenitor Mario Galvez Roa el día 17...
# 2019  14.0  Que a las 13:00 horas, salió del domicilio de ...
#
#                                                clothing  \
# 47    Pantalón jean azul, chompa amarilla con rayas ...
# 72    Una chompa de color coral, pantalón negro, zap...
# ...

# %%
amber_eyes = no_brown_eyes[no_brown_eyes['eyes_color'].str.contains('AMB|MIEL').fillna(False)]
amber_eyes
# Out:
#        age                                      circumstances  \
# 72    13.0  En que salió de su domicilio ubicado en Jr. Hu...
# 101   15.0                             Salió de su domicilio.
# 156   15.0                  Salió con dirección a su colegio.
# 179   16.0                   Salió del mercado Nuevo Huánuco.
# 249   16.0                                                NaN
# 271   13.0                             Salió de su domicilio.
# 290   14.0    Salió de su domicilio con dirección al colegio.
# 343   12.0                              Salió de su domicilio
# 473   13.0  Salió del instituto de idiomas El británico, e...
# 544   16.0                             Salió de su domicilio.
# 556   16.0                             Salió de su domicilio.
# 561   10.0                                                NaN
# 661   15.0  Salió de su domicilio hacia su colegio Adventi...
# 684   14.0  Salió de su domicilio con dirección al Mercado...
# ...

# %%
no_amber_eyes = no_brown_eyes[~no_brown_eyes['eyes_color'].str.contains('AMB|MIEL').fillna(False)]
no_amber_eyes
# Out:
#        age                                      circumstances  \
# 47    16.0                             Salió de su domicilio.
# 104   14.0                                                NaN
# 105   14.0                                     Salió de casa.
# 158   14.0                             Salió de su domicilio.
# 159   14.0                                      Se desconoce.
# ...    ...                                                ...
# 1980  15.0  Que salió de su domicilio ubicado en Block Q15...
# 1983  14.0  En horas de madrugada se fugó  de su hogar en ...
# 1986  16.0  En horas de la madrugada se fugó de su hogar e...
# 2016   7.0  Según su progenitor Mario Galvez Roa el día 17...
# 2019  14.0  Que a las 13:00 horas, salió del domicilio de ...
#
#                                                clothing  \
# 47    Pantalón jean azul, chompa amarilla con rayas ...
# 104   Polera rosada, pantalón negro y zapatilla blanca.
# ...

# %%
gray_eyes = no_amber_eyes[no_amber_eyes['eyes_color'].str.contains('GRI').fillna(False)]
gray_eyes
# Out:
#        age                                      circumstances  \
# 47    16.0                             Salió de su domicilio.
# 158   14.0                             Salió de su domicilio.
# 312    NaN                             Salió de su domicilio
# 526   13.0                              Salió de su domicilio
# 555   11.0                              Salió de su domicilio
# 570   13.0                              Salió de si domicilio
# 621   16.0                             Salió de su domicilio.
# 658   17.0                             Salió de su domicilio.
# 726   14.0  La madre la dejó en la puerta del colegio a la...
# 740   14.0  Salió de su domicilio con dirección al colegio...
# 775   15.0          Salió con destino a un local de Internet.
# 868   15.0  El menor habría salido de su domicilio con dir...
# 936   11.0  Se retiró de su domicilio, debido a que su mad...
# 945   14.0  Salió de su domicilio con la finalidad de comp...
# ...

# %%
no_gray_eyes = no_amber_eyes[~no_amber_eyes['eyes_color'].str.contains('GRI').fillna(False)]
no_gray_eyes
# Out:
#        age                                      circumstances  \
# 104   14.0                                                NaN
# 105   14.0                                     Salió de casa.
# 159   14.0                                      Se desconoce.
# 174   14.0                                                NaN
# 183   16.0                                                NaN
# ...    ...                                                ...
# 1980  15.0  Que salió de su domicilio ubicado en Block Q15...
# 1983  14.0  En horas de madrugada se fugó  de su hogar en ...
# 1986  16.0  En horas de la madrugada se fugó de su hogar e...
# 2016   7.0  Según su progenitor Mario Galvez Roa el día 17...
# 2019  14.0  Que a las 13:00 horas, salió del domicilio de ...
#
#                                                clothing  \
# 104   Polera rosada, pantalón negro y zapatilla blanca.
# 105   Polera roja, pantalón azul, zapatilla negra y ...
# ...

# %%
green_eyes = no_gray_eyes[no_gray_eyes['eyes_color'].str.contains('VER').fillna(False)]
green_eyes
# Out:
#        age                                      circumstances  \
# 183   16.0                                                NaN
# 438   16.0       Salió de su domicilio con rumbo desconocido.
# 453   16.0       Salió de su domicilio con rumbo desconocido.
# 543   12.0  Transitaba por las inmediaciones de la Av. Avi...
# 772   14.0                Cuando  se encontraba sola en casa.
# 1102  12.0          Salió de su colegio San Agustín de Jauja.
# 1645  17.0  Salía de su domicilio rumbo al Instituto Britá...
# 1713  16.0                                                NaN
# 1741  15.0  El menor salió de su domicilio sin decir nada....
# 1964  13.0  Salió de su domicilio, ubicado en Jr. Bolivar ...
#
#                                                clothing  \
# 183   Polera ploma con capucha, pantalón de buzo neg...
# 438   Buzo completo, pantalón de buzo azul con rayas...
# 453   Buzo completo, pantalón de buzo azul con rayas...
# ...

# %%
no_green_eyes = no_gray_eyes[~no_gray_eyes['eyes_color'].str.contains('VER').fillna(False)]
no_green_eyes
# Out:
#        age                                      circumstances  \
# 104   14.0                                                NaN
# 105   14.0                                     Salió de casa.
# 159   14.0                                      Se desconoce.
# 174   14.0                                                NaN
# 215   16.0        Salió de su domicilio abordando un minubus.
# ...    ...                                                ...
# 1980  15.0  Que salió de su domicilio ubicado en Block Q15...
# 1983  14.0  En horas de madrugada se fugó  de su hogar en ...
# 1986  16.0  En horas de la madrugada se fugó de su hogar e...
# 2016   7.0  Según su progenitor Mario Galvez Roa el día 17...
# 2019  14.0  Que a las 13:00 horas, salió del domicilio de ...
#
#                                                clothing  \
# 104   Polera rosada, pantalón negro y zapatilla blanca.
# 105   Polera roja, pantalón azul, zapatilla negra y ...
# ...

# %%
hazel_eyes = no_green_eyes[no_green_eyes['eyes_color'].str.contains('AVELL').fillna(False)]
hazel_eyes
# Out:
#        age                                   circumstances  \
# 159   14.0                                   Se desconoce.
# 651   16.0                      Con dirección a su colegio
# 782   13.0                                             NaN
# 797   13.0                                             NaN
# 1059  14.0  Se dirigía a su domicilio Jr. Las Violetas 779
# 1425  14.0                  Cuando salió de su domicilio.
#
#                                                clothing  \
# 159   Casaca de buzo azul con blanco y pantalón de b...
# 651   Ropa de educación física con el logotipo de la...
# 782   Pijama color fucsia, pantalón con blanco con d...
# 797   Pijama color fucsia, pantalón con blanco con d...
# 1059  Casaca color anaranjada, pantalón jean color n...
# 1425                                                NaN
#
#                            complaint_date         disappearance_date  \
# 159      Jueves, 24 Octubre, 2019 - 00:00  2019-10-22T00:00:00-05:00
# ...

# %%
no_green_eyes['eyes_color'].value_counts()
# Out:
# REDONDOS          15
# MEDIANOS          10
# PEQUEÑOS           9
# GRANDES            8
# UNDEFINED          8
# ALBINOS            5
# AVELLANA           4
# ALBINO             4
# Rasgados           4
# COLOR AVELLANA     2
# JALADOS            1
# CHICOS             1
# HUNDIDOS           1
# ASIÁTICOS          1
# Pardo y negro      1
# AZULES             1
# Name: eyes_color, dtype: int64

# %% [markdown]
# # Index and selection

# %%
# dictionary like
t_e_b_encontrados['name']
# Out:
# 0          Pricila Dayana Merino Gallo
# 1            Azumi Katiuzca Suárez Meza
# 2        Luz Aylem Quehuarucho Fuentes
# 3       Angely Mildreth Caceres Guzmán
# 4             Luis Ángel Quispe Machuca
#                      ...
# 2013      Vargas Cacique Monica Erminia
# 2014      Porras Huaman Thalia Dionisia
# 2015             Salas Vera Joel Adrián
# 2016     Rojas Fernandez Verónica Sofía
# 2017        Rocío Pilar Zorrilla Vargas
# Name: name, Length: 2018, dtype: object

# %%
t_e_b_encontrados[['name', 'age']]
# Out:
#                                  name   age
# 0        Pricila Dayana Merino Gallo   14.0
# 1          Azumi Katiuzca Suárez Meza  14.0
# 2      Luz Aylem Quehuarucho Fuentes   10.0
# 3     Angely Mildreth Caceres Guzmán   12.0
# 4           Luis Ángel Quispe Machuca  11.0
# ...                               ...   ...
# 2013    Vargas Cacique Monica Erminia  16.0
# 2014    Porras Huaman Thalia Dionisia  15.0
# 2015           Salas Vera Joel Adrián  14.0
# 2016   Rojas Fernandez Verónica Sofía  17.0
# 2017      Rocío Pilar Zorrilla Vargas  12.0
#
# [2018 rows x 2 columns]

# %%
# numpy like
t_e_b_encontrados.iloc[16]
# Out:
# age                                                                  15
# circumstances         Fugó en horas de la madrugada de la aldea infa...
# clothing              Casaca negra, pantalón de buzo negro y zapatil...
# complaint_date                      Domingo, 10 Noviembre, 2019 - 00:00
# disappearance_date                            2019-11-10T00:00:00-05:00
#                                             ...
# nose                                                              RECTA
# province                                                    Andahuaylas
# race                                                            MESTIZA
# state                                                          Apurímac
# url                   https://teestamosbuscando.pe//desaparecido/lui...
# Name: 16, Length: 19, dtype: object

# %%
t_e_b_encontrados.iloc[16]['name']
# Out:
# 'Roberto Yslachin Allcca '

# %%
t_e_b_encontrados.iloc[:5, 13]
# Out:
# 0       Pricila Dayana Merino Gallo
# 1         Azumi Katiuzca Suárez Meza
# 2     Luz Aylem Quehuarucho Fuentes
# 3    Angely Mildreth Caceres Guzmán
# 4          Luis Ángel Quispe Machuca
# Name: name, dtype: object

# %%
t_e_b_encontrados.loc[:, ['name', 'state', 'province', 'district']]
# Out:
#                                  name   state                 province  \
# 0        Pricila Dayana Merino Gallo   Callao  Prov. Const. del Callao
# 1          Azumi Katiuzca Suárez Meza    Lima                     Lima
# 2      Luz Aylem Quehuarucho Fuentes      NaN                      NaN
# 3     Angely Mildreth Caceres Guzmán    Cusco                    Cusco
# 4           Luis Ángel Quispe Machuca    Lima                     Lima
# ...                               ...     ...                      ...
# 2013    Vargas Cacique Monica Erminia    Lima                     Lima
# 2014    Porras Huaman Thalia Dionisia    Lima                     Lima
# 2015           Salas Vera Joel Adrián    Lima                     Lima
# 2016   Rojas Fernandez Verónica Sofía    Lima                     Lima
# 2017      Rocío Pilar Zorrilla Vargas   Junín                 Huancayo
#
#                   district
# 0                  Mi Perú
# 1              Santa Anita
# 2                    Cusco
# ...

# %% [markdown]
# # Data wrangling

# %%
# 1. Add site_uid to the DataFrame

t_e_b_encontrados['site_uid'] = 'teestamosbuscando-encontrados'

t_e_b_encontrados
# Out:
#        age                                      circumstances  \
# 0     14.0                                 Salió de su casa.
# 1     14.0                              Salió de su domicilio
# 2     10.0  Por las inmediaciones del colegio Clorinda Mat...
# 3     12.0  Por las inmediaciones de la Cooperativa Franci...
# 4     11.0                    Salió del colegio y no retornó.
# ...    ...                                                ...
# 2013  16.0  Que se encontraba en la casa a las 12:00 horas...
# 2014  15.0  Salio de su domicilio sin indicar a donde se d...
# 2015  14.0  El 14 de octubre del 2017 a horas 07:30 aprox....
# 2016  17.0         Salió de su domicilio sin indicar destino.
# 2017  12.0  Salió del puesto de pollos ubicado en la Av. H...
#
#                                                clothing  \
# 0                      Chompa blanca y pantalón morado.
# 1         Polo anaranjado, buzo azul zapatillas negras.
# ...

# %%
# Get the host
from urllib.parse import urlparse

t_e_b_encontrados['host'] = t_e_b_encontrados['url'].apply(lambda url: urlparse(url).netloc)

t_e_b_encontrados
# Out:
#        age                                      circumstances  \
# 0     14.0                                 Salió de su casa.
# 1     14.0                              Salió de su domicilio
# 2     10.0  Por las inmediaciones del colegio Clorinda Mat...
# 3     12.0  Por las inmediaciones de la Cooperativa Franci...
# 4     11.0                    Salió del colegio y no retornó.
# ...    ...                                                ...
# 2013  16.0  Que se encontraba en la casa a las 12:00 horas...
# 2014  15.0  Salio de su domicilio sin indicar a donde se d...
# 2015  14.0  El 14 de octubre del 2017 a horas 07:30 aprox....
# 2016  17.0         Salió de su domicilio sin indicar destino.
# 2017  12.0  Salió del puesto de pollos ubicado en la Av. H...
#
#                                                clothing  \
# 0                      Chompa blanca y pantalón morado.
# 1         Polo anaranjado, buzo azul zapatillas negras.
# ...

# %%
t_e_b_encontrados['host'].value_counts()
# Out:
# teestamosbuscando.pe    2018
# Name: host, dtype: int64

# %% [markdown]
# # Missing data

# %%
# 3. Fill missing data

missing_names_mask = t_e_b_encontrados['name'].isna()

# missing_names_mask

# te_estamos_buscando[missing_names_mask]['url'].str.extract(r'(?P<missing_name>[^/]+)$')
missing_names = (te_estamos_buscando['url']
                    .str.extract(r'(?P<missing_names>[^/]+)$')
                    .applymap(lambda name: name.split('-'))
                    .applymap(lambda name_word_list: ' '.join(name_word_list))
               )

missing_names
# Out:
#                                missing_names
# 0                 flor de maria melo escobar
# 1                laura sof%C3%ADa mariz ruiz
# 2             nahomi kiara v%C3%A1squez meza
# 3          evelyn greys esteves v%C3%ADlchez
# 4             yarja nefec huayhua p%C3%A9rez
# ..                                       ...
# 19      fernando rovi%C3%B1o salgado palacin
# 20             valeria danna pacheco mendoza
# 21  joel adri%C3%A1n tantavilca mu%C3%B1oz 0
# 22              kiara estefany rojas armas 0
# 23        delby esther v%C3%A1squez capcha 0
#
# [24 rows x 1 columns]

# %%
te_estamos_buscando.loc[missing_names_mask, 'name'] = missing_names.loc[:, 'missing_names']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     190         try:
# --> 191             return self._convert_to_indexer(key, axis=axis, is_setter=True)
#     192         except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1085                 key = self._convert_for_reindex(key, axis)
# -> 1086             indexer = ax.get_indexer_for(key)
# ...

# %% [markdown]
# # Aditional cleanup

# %%
# 4. add uid to the rows
import hashlib

uids = (t_e_b_encontrados
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
       )

t_e_b_encontrados['uid'] = uids
t_e_b_encontrados.set_index('uid', inplace=True)

t_e_b_encontrados
# Out:
#                                    age  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71  14.0
# 168799150380f1868ff680421262d4ac  14.0
# 2f83a71d9707efc7f0620943d85e3689  10.0
# b6c675d72115e213feb2790a4fd60a76  12.0
# d1512008b416e9f2f78788143c271e51  11.0
# ...                                ...
# c4969f9937657cc39b76510ba2197f9c  16.0
# a6a7519e2b998d312b4d31e3e82af1a4  15.0
# f6230c65230c4852b25db12df5380f61  14.0
# eeb5cec0b8d87ffe21aac70f8ff27789  17.0
# b76785f4951224db7abc78a47af70564  12.0
#
#                                                                       circumstances  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71                                 Salió de su casa.
# 168799150380f1868ff680421262d4ac                              Salió de su domicilio
# 2f83a71d9707efc7f0620943d85e3689  Por las inmediaciones del colegio Clorinda Mat...
# b6c675d72115e213feb2790a4fd60a76  Por las inmediaciones de la Cooperativa Franci...
# ...

# %%
stripped_body = (te_estamos_buscando
                     .apply(lambda row:row['body'], axis=1)
                  targs for laun   .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letters.replace('\n', ''), letters)))
                     .apply(lambda letters: ''.join(letter))
                )

# %% [markdown]
# # Data enrichment

# %%
# 6. tokenize properties
import nltk
from nltk.corpus import stopwords

# nltk.download('punkt')
# nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
                .dropna()
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                .apply(lambda valid_word_list: len(valid_word_list))
            )

t_e_b_encontrados['n_tokens_circumstances'] = tokenize_column(t_e_b_encontrados, 'circumstances')

t_e_b_encontrados
# Out:
#                                    age  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71  14.0
# 168799150380f1868ff680421262d4ac  14.0
# 2f83a71d9707efc7f0620943d85e3689  10.0
# b6c675d72115e213feb2790a4fd60a76  12.0
# d1512008b416e9f2f78788143c271e51  11.0
# ...                                ...
# eeb5cec0b8d87ffe21aac70f8ff27789  17.0
# c4969f9937657cc39b76510ba2197f9c  16.0
# a6a7519e2b998d312b4d31e3e82af1a4  15.0
# f6230c65230c4852b25db12df5380f61  14.0
# b76785f4951224db7abc78a47af70564  12.0
#
#                                                                       circumstances  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71                                 Salió de su casa.
# 168799150380f1868ff680421262d4ac                              Salió de su domicilio
# 2f83a71d9707efc7f0620943d85e3689  Por las inmediaciones del colegio Clorinda Mat...
# b6c675d72115e213feb2790a4fd60a76  Por las inmediaciones de la Cooperativa Franci...
# ...

# %% [markdown]
# # Duplicate values

# %%
# 8. Delete duplicate values

t_e_b_encontrados['name'].value_counts()
# Out:
# Bryan Aldair Pariona Encarnación     4
# Gao Ocharan Carlos Antonio           3
# Sahimy Lizbeth Asto Campos           3
# Jessica Maribel Quepuy Castillo      2
# Edwin Gabriel Mamani Valenzuela      2
#                                     ..
# Yuneth Mishell Majino Victorio       1
# Heydi Maribel Salón Salas            1
# Gael Torres Ugaz                     1
# Pamela Zaraí Inca Huamán             1
#  Héctor Abel Chávez Ramos            1
# Name: name, Length: 1948, dtype: int64

# %%
t_e_b_encontrados[t_e_b_encontrados['hair_color'] == 'COLOR NEGRO']
# Out:
#                                    age  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71  14.0
# d1512008b416e9f2f78788143c271e51  11.0
# 7c213942a3fecd715c99d655c1808a94  15.0
# 86736252097f6256c9bf7c52028de75e  15.0
# f92dbd2cff419ecb82b2048721db4eaa  16.0
# ...                                ...
# ceaae252db76eb407a9afb3f60217597  16.0
# cf2609d212b0d61817a34deb270fcf25  14.0
# cc244b0dd5d839cac78e384d3d7e9214  13.0
# 1fb3a247cbfacbfcbf9dda7e51a300ef  17.0
# 91773664c7912ababf95058425170ae4  12.0
#
#                                                                       circumstances  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71                                 Salió de su casa.
# d1512008b416e9f2f78788143c271e51                    Salió del colegio y no retornó.
# 7c213942a3fecd715c99d655c1808a94                     Salió del domicilio de su tía.
# 86736252097f6256c9bf7c52028de75e  Fugó en horas de la madrugada de la aldea infa...
# ...

# %%
t_e_b_encontrados.drop_duplicates(subset=['name'], keep='first', inplace=True)

# %% [markdown]
# # Final table

# %%
# Final table

t_e_b_encontrados
# Out:
#                                    age  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71  14.0
# 168799150380f1868ff680421262d4ac  14.0
# 2f83a71d9707efc7f0620943d85e3689  10.0
# b6c675d72115e213feb2790a4fd60a76  12.0
# d1512008b416e9f2f78788143c271e51  11.0
# ...                                ...
# eeb5cec0b8d87ffe21aac70f8ff27789  17.0
# c4969f9937657cc39b76510ba2197f9c  16.0
# a6a7519e2b998d312b4d31e3e82af1a4  15.0
# f6230c65230c4852b25db12df5380f61  14.0
# b76785f4951224db7abc78a47af70564  12.0
#
#                                                                       circumstances  \
# uid
# 7a6957d1f250c29ee7f99ccdc7e00c71                                 Salió de su casa.
# 168799150380f1868ff680421262d4ac                              Salió de su domicilio
# 2f83a71d9707efc7f0620943d85e3689  Por las inmediaciones del colegio Clorinda Mat...
# b6c675d72115e213feb2790a4fd60a76  Por las inmediaciones de la Cooperativa Franci...
# ...

# %% [markdown]
# # Combining dataset

# %% [markdown]
# # Descriptive analysis

# %%
clean_teestamosbuscando = pd.read_csv('clean_teestamosbuscando_2019_10_27_people_profiles.csv')

# %%
clean_teestamosbuscando.describe()
# Out:
#              age     height  n_tokens_circumstances
# count  17.000000  17.000000               17.000000
# mean   13.588235   1.535882                3.470588
# std     2.717049   0.112753                1.940285
# min     4.000000   1.200000                1.000000
# 25%    13.000000   1.500000                2.000000
# 50%    14.000000   1.580000                3.000000
# 75%    15.000000   1.600000                4.000000
# max    17.000000   1.650000                8.000000

# %%
# %matplotlib inline

# %%
clean_teestamosbuscando['age'].plot(style='k.')

# %%
grouped = clean_teestamosbuscando.groupby('site_uid')
grouped.hist()
# Out:
# site_uid
# teestamosbuscando    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# dtype: object

# %%
grouped['n_tokens_circumstances'].agg(['min', 'mean', 'max'])
# Out:
#                    min      mean  max
# site_uid
# teestamosbuscando  1.0  3.470588  8.0

# %%
grouped.plot()
# Out:
# site_uid
# teestamosbuscando    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
